# %%
import pandas as pd
import numpy as np
import os

# %%
dataframes = {}
for filename in os.listdir():
    if filename.endswith(".xlsx"):
        filepath = os.path.join(filename)
        # Use the filename (without extension) as the DataFrame name
        dataframe_name = os.path.splitext(filename)[0]
        # Read the Excel file into a DataFrame
        dataframes[dataframe_name] = pd.read_excel(filepath)

# Example: Accessing individual DataFrames
for name, df in dataframes.items():
    print(f"DataFrame Name: {name}")
# Out:
# DataFrame Name: LaLiga123 16 17
# DataFrame Name: LaLiga123 17 18
# DataFrame Name: LaLiga123 18 19
# DataFrame Name: LaLiga123 19 20
# DataFrame Name: LaLiga123 20 21
# DataFrame Name: LaLiga123 21 22
# DataFrame Name: LaLiga16 17
# DataFrame Name: LaLiga17 18
# DataFrame Name: LaLiga18 19
# DataFrame Name: LaLiga19 20
# DataFrame Name: LaLiga20 21
# DataFrame Name: LaLiga21 22

# %%
dataframes['LaLiga123 16 17']
# Out:
#                  Round    Wk  Day       Date           Time       Local Score  \
# 0    Temporada Regular   1.0  Vie 2016-08-19  20:00 (15:00)    Mirandés   1–1
# 1    Temporada Regular   1.0  Vie 2016-08-19  22:00 (17:00)     Almería   1–1
# 2    Temporada Regular   1.0  Sáb 2016-08-20  19:00 (14:00)       Elche   2–1
# 3    Temporada Regular   1.0  Sáb 2016-08-20  19:00 (14:00)    Alcorcón   0–0
# 4    Temporada Regular   1.0  Sáb 2016-08-20  19:00 (14:00)    Mallorca   0–1
# ..                 ...   ...  ...        ...            ...         ...   ...
# 495  Temporada Regular  42.0  Sáb 2017-06-10  20:30 (14:30)  Valladolid   1–0
# 496  Temporada Regular  42.0  Sáb 2017-06-10  20:30 (14:30)   Gimnàstic   1–0
# 497  Temporada Regular  42.0  Sáb 2017-06-10  20:30 (14:30)    Alcorcón   3–0
# 498  Temporada Regular  42.0  Sáb 2017-06-10  20:30 (14:30)     Córdoba   2–1
# 499  Temporada Regular  42.0  Sáb 2017-06-10  20:30 (14:30)    Zaragoza   1–2
#
# ...

# %%
dataframes['LaLiga21 22']
# Out:
#        Wk  Day       Date           Time          Local   xG Score  xG.1  \
# 0     1.0  Vie 2021-08-13  21:00 (15:00)       Valencia  1.3   1–0   1.2
# 1     1.0  Sáb 2021-08-14  19:30 (13:30)          Cádiz  0.4   1–1   1.0
# 2     1.0  Sáb 2021-08-14  19:30 (13:30)       Mallorca  0.4   1–1   0.9
# 3     1.0  Sáb 2021-08-14  22:00 (16:00)        Osasuna  0.8   0–0   0.7
# 4     1.0  Sáb 2021-08-14  22:00 (16:00)         Alavés  1.7   1–4   1.8
# ..    ...  ...        ...            ...            ...  ...   ...   ...
# 419  38.0  Dom 2022-05-22  20:00 (14:00)         Alavés  0.4   0–1   1.9
# 420  38.0  Dom 2022-05-22  20:00 (14:00)        Granada  2.0   0–0   0.4
# 421  38.0  Dom 2022-05-22  22:00 (16:00)  Real Sociedad  2.3   1–2   0.8
# 422  38.0  Dom 2022-05-22  22:00 (16:00)      Barcelona  0.7   0–2   0.7
# 423  38.0  Dom 2022-05-22  22:00 (16:00)        Sevilla  1.4   1–0   0.7
#
#            Visitante  Attendance                          Venue  \
# ...
