# %%
import numpy as np
import pandas as pd

# %%
col1 = np.linspace(1,100,30, dtype=int)
col2 = np.linspace(1,5,30, dtype=float)

# %%
df = pd.DataFrame({
    'col1':col1,
    'col2':col2
})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = pd.DataFrame({
#       2     'col1':col1,
#       3     'col2':col2
#       4 })
#
# NameError: name 'pd' is not defined
