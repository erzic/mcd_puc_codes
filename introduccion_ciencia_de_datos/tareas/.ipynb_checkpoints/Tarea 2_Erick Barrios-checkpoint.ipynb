# %%
#código de inicio
import pandas as pd
import numpy as np

# %% [markdown]
# # <img style="float: left; padding-right: 20px; width: 100px" src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/84/Escudo_de_la_Pontificia_Universidad_Cat%C3%B3lica_de_Chile.svg/1920px-Escudo_de_la_Pontificia_Universidad_Cat%C3%B3lica_de_Chile.svg.png"> MCD3020 - Introducción a Ciencia de Datos
# **Pontificia Universidad Católica de Chile**<br>
# **Magíster en Ciencia de Datos**<br>
# **2022**<br>
#
# ----

# %% [markdown]
# # Tarea 2: Limpieza y combinación de datos.
#
# ***
# ## Instrucciones Generales:
# - Esta Tarea debe ser desarrollada completamente en lenguaje de programación Python, en este mismo Notebook.
# - El Notebook debe estar  ordenado, seguir buenas prácticas de escritura y programación, e incluir comentarios o celdas de markdown suficientes para explicar claramente todos lo códigos computacionales.
# - El Notebook ya contiene algunas celdas marcadas con el comentario `#código de inicio`. Estas celdas han sido incluidas como ayuda para el desarrollo de la Tarea, y pueden ser ejecutadas tal como están.
# - Las celdas marcadas como `#completar código` tienen un código parcial que debe ser completado para poder ser ejecutado. Ud debe agregar todas las líneas o bloques de código necesarios para desarrollar correctamente cada punto de la tarea. También puede eliminar estas celdas y partir el código desde cero si le resulta más conveniente.
#
# ***
# ## Introducción.
#
# Hace ya casi 10 años, el trabajo de científico de datos fue catalogado por Harvard Bussiness Review como "el trabajo más atractivo del siglo XXI" [(Davenport & Patil 2012)](https://hbr.org/2012/10/data-scientist-the-sexiest-job-of-the-21st-century). Desde entonces, se ha comprobado un aumento constante de la demanda por profesionales expertos datos, y se espera que tanto la creación de puestos trabajos como los salarios sigan al alza en los próximos años. Los siguienes artículos de prensa y difusión ilustran esta situación:
#
# https://www.smithhanley.com/2022/01/04/data-science-in-2022/
# https://www.bbva.com/es/big-data-la-demanda-de-talento-experto-sigue-creciendo/
#
# Los estudios citados hacen referencia a mercados laborales en Europa y Estados Unidos. Suponga que ud.está a cargo del desarrollo de un estudio del mercado laboral de científicos de datos en latinoamérica, para lo cual necesita construir, procesar y analizar una base de datos con las ofertas de trabajo publicadas en distintos países de la región.
#
# En la **Tarea 1**, ud. avanzó en la primera etapa de construcción de la base de datos, utilizando web scraping para extraer los datos de ofertas de empleo en *data science* publicados en la red Linkedin, para una ciudad o país. Este proceso fue repetido y ampliado para todos los países de sudamérica, dando origen a un conjunto de bases de datos que serán su insumos para la siguiente etapa del proceso de ciencia de datos.
#
# Para considerar en el análisis el contexto económico y tecnológico de cada país, entre los datos se incluirán también otras variables como el *Índice global de innovación* (https://www.globalinnovationindex.org/Home), disponible online para distintos países del mundo.
#
# En esta **Tarea 2**, ud. deberá integrar, limpiar y procesar las bases de datos obtenidas de distintas fuentes, de manera de obtener un conjunto de datos apto para distintos tipos de análisis.

# %% [markdown]
# ## Datos de Entrada.
#
# Los datos ofertas laborales de *data science* publicadas en Linkedin para los países de sudamérica están disponibles para lectura o descarga en los siguientes links:
#
# * https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/tarea2/jobsLinkedin_Argentina_t2.csv
# * https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/tarea2/jobsLinkedin_Bolivia_t2.csv
# * https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/tarea2/jobsLinkedin_Brasil_t2.csv
# * https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/tarea2/jobsLinkedin_Chile_t2.csv
# * https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/tarea2/jobsLinkedin_Colombia_t2.csv
# * https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/tarea2/jobsLinkedin_Guyana_t2.csv
# * https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/tarea2/jobsLinkedin_Ecuador_t2.csv
# * https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/tarea2/jobsLinkedin_Paraguay_t2.csv
# * https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/tarea2/jobsLinkedin_Peru_t2.csv
# * https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/tarea2/jobsLinkedin_Suriname_t2.csv
# * https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/tarea2/jobsLinkedin_Uruguay_t2.csv
# * https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/tarea2/jobsLinkedin_Venezuela_t2.csv
#
# Además, se han descargado desde la página https://www.globalinnovationindex.org/analysis-indicator/ los datos de Índice de Innovación Global para el año 2022, disponibles en el siguiente archivo:
#
# https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/tarea2/indiceInnovacionPaises.csv

# %% [markdown]
# ### 1. Lea todos los conjuntos de datos entregados, y concatenelos para generar un único dataframe con todas las ofertas laborales de Data Scientist publicadas en Linkedin para los países de sudamérica.
#
# *Funciones útiles*: `pandas.concat()`

# %%
#completar codigo

locations = ['Chile','Argentina','Peru','Colombia','Ecuador','Brasil','Venezuela','Uruguay','Paraguay','Bolivia','Suriname','Guyana']

alldf=[]

for loc in locations:
    url='https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/tarea2/jobsLinkedin_%s_t2.csv'%loc
    df_tmp = pd.read_csv(url)
    
    alldf.append(df_tmp)
    
    
alldf=pd.concat(alldf, axis=0)

# %%
alldf
# Out:
#     Unnamed: 0 Country                                       Location  \
# 0            0   Chile  Santiago, Santiago Metropolitan Region, Chile
# 1            1   Chile  Santiago, Santiago Metropolitan Region, Chile
# 2            2   Chile  Santiago, Santiago Metropolitan Region, Chile
# 3            3   Chile              Rancagua, O'Higgins Region, Chile
# 4            4   Chile  Santiago, Santiago Metropolitan Region, Chile
# ..         ...     ...                                            ...
# 121        256  Guyana                                         Guyana
# 122        275  Guyana           Georgetown, Demerara-Mahaica, Guyana
# 123        310  Guyana              Mahaica, Demerara-Mahaica, Guyana
# 124        322  Guyana                                         Guyana
# 125        334  Guyana                 No. 3, Mahaica-Berbice, Guyana
#
#                                                  Title         Company  \
# 0                                       Data Scientist       BICE VIDA
# 1                                       Data Scientist      BNamericas
# 2                                      Data Scientist.  Fuerza Laboral
# 3                                       Data Scientist       Agrosuper
# 4                                       Data Scientist   MAS Analytics
# ..                                                 ...             ...
# 121                              Sr. Platform Engineer            Aha!
# 122  Operations Intelligence Performance Optimizati...    SBM Offshore
# 123                              Sr. Platform Engineer            Aha!
# 124                             Ruby on Rails Engineer            Aha!
# 125                                      Data Engineer       Univision
#
#                                                    Url  \
# 0    https://cl.linkedin.com/jobs/view/data-scienti...
# 1    https://cl.linkedin.com/jobs/view/data-scienti...
# 2    https://cl.linkedin.com/jobs/view/data-scienti...
# 3    https://cl.linkedin.com/jobs/view/data-scienti...
# 4    https://cl.linkedin.com/jobs/view/data-scienti...
# ..                                                 ...
# 121  https://gy.linkedin.com/jobs/view/sr-platform-...
# 122  https://gy.linkedin.com/jobs/view/operations-i...
# 123  https://gy.linkedin.com/jobs/view/sr-platform-...
# 124  https://gy.linkedin.com/jobs/view/ruby-on-rail...
# 125  https://gy.linkedin.com/jobs/view/data-enginee...
#
#                             Postulaciones  \
# 0                                     NaN
# 1    \n          42 solicitudes\n
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 121                                   NaN
# 122                                   NaN
# 123                                   NaN
# 124                                   NaN
# 125                                   NaN
#
#                                     Jornada  \
# 0    \n          Jornada completa\n
# 1    \n          Jornada completa\n
# 2    \n          Jornada completa\n
# 3    \n          Jornada completa\n
# 4    \n          Jornada completa\n
# ..                                      ...
# 121                                     NaN
# 122         \n          Full-time\n
# 123         \n          Full-time\n
# 124         \n          Full-time\n
# 125         \n          Full-time\n
#
#                                      Antiguedad
# 0      \n            No corresponde\n
# 1     \n            Sin experiencia\n
# 2     \n            Sin experiencia\n
# 3          \n            Intermedio\n
# 4      \n            No corresponde\n
# ..                                          ...
# 121                                         NaN
# 122       \n            Entry level\n
# 123  \n            Mid-Senior level\n
# 124       \n            Entry level\n
# 125       \n            Entry level\n
#
# [1023 rows x 9 columns]

# %% [markdown]
# ### 2. ¿Existe alguna columna innecesaria o inútil en su dataframe? Justifique, y en caso necesario, elimine la(s) columna(s) de sobra.

# %% [markdown]
# **Respuesta**:
# Una columna innecesaria es Unnamed: 0 pues no nos proporciona mayor información. Es un correlativo relativo a cada dataframe individual

# %%
alldf = alldf.drop('Unnamed: 0', axis=1)
alldf
# Out:
#     Country                                       Location  \
# 0     Chile  Santiago, Santiago Metropolitan Region, Chile
# 1     Chile  Santiago, Santiago Metropolitan Region, Chile
# 2     Chile  Santiago, Santiago Metropolitan Region, Chile
# 3     Chile              Rancagua, O'Higgins Region, Chile
# 4     Chile  Santiago, Santiago Metropolitan Region, Chile
# ..      ...                                            ...
# 121  Guyana                                         Guyana
# 122  Guyana           Georgetown, Demerara-Mahaica, Guyana
# 123  Guyana              Mahaica, Demerara-Mahaica, Guyana
# 124  Guyana                                         Guyana
# 125  Guyana                 No. 3, Mahaica-Berbice, Guyana
#
#                                                  Title         Company  \
# 0                                       Data Scientist       BICE VIDA
# 1                                       Data Scientist      BNamericas
# 2                                      Data Scientist.  Fuerza Laboral
# 3                                       Data Scientist       Agrosuper
# 4                                       Data Scientist   MAS Analytics
# ..                                                 ...             ...
# 121                              Sr. Platform Engineer            Aha!
# 122  Operations Intelligence Performance Optimizati...    SBM Offshore
# 123                              Sr. Platform Engineer            Aha!
# 124                             Ruby on Rails Engineer            Aha!
# 125                                      Data Engineer       Univision
#
#                                                    Url  \
# 0    https://cl.linkedin.com/jobs/view/data-scienti...
# 1    https://cl.linkedin.com/jobs/view/data-scienti...
# 2    https://cl.linkedin.com/jobs/view/data-scienti...
# 3    https://cl.linkedin.com/jobs/view/data-scienti...
# 4    https://cl.linkedin.com/jobs/view/data-scienti...
# ..                                                 ...
# 121  https://gy.linkedin.com/jobs/view/sr-platform-...
# 122  https://gy.linkedin.com/jobs/view/operations-i...
# 123  https://gy.linkedin.com/jobs/view/sr-platform-...
# 124  https://gy.linkedin.com/jobs/view/ruby-on-rail...
# 125  https://gy.linkedin.com/jobs/view/data-enginee...
#
#                             Postulaciones  \
# 0                                     NaN
# 1    \n          42 solicitudes\n
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 121                                   NaN
# 122                                   NaN
# 123                                   NaN
# 124                                   NaN
# 125                                   NaN
#
#                                     Jornada  \
# 0    \n          Jornada completa\n
# 1    \n          Jornada completa\n
# 2    \n          Jornada completa\n
# 3    \n          Jornada completa\n
# 4    \n          Jornada completa\n
# ..                                      ...
# 121                                     NaN
# 122         \n          Full-time\n
# 123         \n          Full-time\n
# 124         \n          Full-time\n
# 125         \n          Full-time\n
#
#                                      Antiguedad
# 0      \n            No corresponde\n
# 1     \n            Sin experiencia\n
# 2     \n            Sin experiencia\n
# 3          \n            Intermedio\n
# 4      \n            No corresponde\n
# ..                                          ...
# 121                                         NaN
# 122       \n            Entry level\n
# 123  \n            Mid-Senior level\n
# 124       \n            Entry level\n
# 125       \n            Entry level\n
#
# [1023 rows x 8 columns]

# %% [markdown]
# ### 3. Tratamiento de datos duplicados.
# **a)** ¿Existen datos duplicados en su dataframe? En caso afirmativo, ¿cuántos son, y se trata de duplicados totales o parciales? Justifique.
#
# **b)** En caso de existir duplicados, defina qué medida de corrección le parece apropiada (eliminar, corregir, combinar registros, etc), y aplíquela.
#
# *Funciones útiles*: `pandas.duplicated()`,`pandas.drop_duplicates()`

# %% [markdown]
# **Respuesta**:
# a) Existen un total de 46 filas duplicadas en el dataframe, tomando en cuenta todas las columnas. Son duplicados totales
# b) Podemos eliminar duplicados en base a la columna de URL pues una posición debe de estar asociada a un solo URL. Otra opción es eliminar duplicados en base a todas las columnas, pero considero que es más ineficiente.

# %%
len(alldf.loc[alldf.duplicated(keep=False), :])
# Out:
# 46

# %%
alldf.loc[alldf.duplicated(keep=False), :]
# Out:
#        Country                                       Location  \
# 67       Chile  Santiago, Santiago Metropolitan Region, Chile
# 75       Chile  Santiago, Santiago Metropolitan Region, Chile
# 7     Colombia                      Colombia, Huila, Colombia
# 36    Colombia       Bogota, D.C., Capital District, Colombia
# 72    Colombia       Bogota, D.C., Capital District, Colombia
# 73    Colombia                      Colombia, Huila, Colombia
# 41     Ecuador                      Italia, Los Ríos, Ecuador
# 61     Ecuador                         Cuenca, Azuay, Ecuador
# 99     Ecuador                      Italia, Los Ríos, Ecuador
# 100    Ecuador                         Cuenca, Azuay, Ecuador
# 36      Brasil                   São Paulo, São Paulo, Brazil
# 44      Brasil                        Maringá, Paraná, Brazil
# 100     Brasil                   São Paulo, São Paulo, Brazil
# 101     Brasil                        Maringá, Paraná, Brazil
# 33   Venezuela                                      Venezuela
# 66   Venezuela                    Anzoategui State, Venezuela
# 95   Venezuela                    Anzoategui State, Venezuela
# 96   Venezuela                                      Venezuela
# 2      Uruguay                Montevideo, Montevideo, Uruguay
# 71     Uruguay                Montevideo, Montevideo, Uruguay
# 100    Uruguay                Montevideo, Montevideo, Uruguay
# 101    Uruguay                Montevideo, Montevideo, Uruguay
# 42    Paraguay                                       Paraguay
# 58    Paraguay                             Asunción, Paraguay
# 94    Paraguay                                       Paraguay
# 95    Paraguay                             Asunción, Paraguay
# 12     Bolivia                                        Bolivia
# 57     Bolivia                Cochabamba, Cochabamba, Bolivia
# 65     Bolivia                Cochabamba, Cochabamba, Bolivia
# 91     Bolivia                                        Bolivia
# 120    Bolivia                Cochabamba, Cochabamba, Bolivia
# 121    Bolivia                                        Bolivia
# 122    Bolivia                Cochabamba, Cochabamba, Bolivia
# 123    Bolivia                                        Bolivia
# 11      Guyana                                         Guyana
# 30      Guyana           Georgetown, Demerara-Mahaica, Guyana
# 65      Guyana              Mahaica, Demerara-Mahaica, Guyana
# 77      Guyana                                         Guyana
# 85      Guyana           Georgetown, Demerara-Mahaica, Guyana
# 89      Guyana                 No. 3, Mahaica-Berbice, Guyana
# 120     Guyana           Georgetown, Demerara-Mahaica, Guyana
# 121     Guyana                                         Guyana
# 122     Guyana           Georgetown, Demerara-Mahaica, Guyana
# 123     Guyana              Mahaica, Demerara-Mahaica, Guyana
# 124     Guyana                                         Guyana
# 125     Guyana                 No. 3, Mahaica-Berbice, Guyana
#
#                                                  Title             Company  \
# 67                                      Data Scientist          PMA Design
# 75                                      Data Scientist          PMA Design
# 7                        Data Science Spark - Colombia      CINTE Colombia
# 36                                      Data Scientist               Chubb
# 72                                      Data Scientist               Chubb
# 73                       Data Science Spark - Colombia      CINTE Colombia
# 41                        DevOps Engineer Junior (m/f)        Michael Page
# 61                             Senior Python Developer       Launch Potato
# 99                        DevOps Engineer Junior (m/f)        Michael Page
# 100                            Senior Python Developer       Launch Potato
# 36                               CIENTISTA DE DADOS JR      Cogna Educação
# 44                    Cientista de Dados - Home Office    Trade Technology
# 100                              CIENTISTA DE DADOS JR      Cogna Educação
# 101                   Cientista de Dados - Home Office    Trade Technology
# 33                             software engineer mobil               TUTEN
# 66   Software Engineer, Trilogy (Remote) - $100,000...  Crossover for Work
# 95   Software Engineer, Trilogy (Remote) - $100,000...  Crossover for Work
# 96                             software engineer mobil               TUTEN
# 2                 Desarrollador Junior [Python /React]            FRIEDMAN
# 71                            Test Automation Engineer             Globant
# 100                           Test Automation Engineer             Globant
# 101               Desarrollador Junior [Python /React]            FRIEDMAN
# 42         React/C# Fullstack Developer (LATAM Remote)           Qeystroke
# 58                                  Desarrollador Java    Experis Paraguay
# 94         React/C# Fullstack Developer (LATAM Remote)           Qeystroke
# 95                                  Desarrollador Java    Experis Paraguay
# 12                               Remote Perl Developer     Scopic Software
# 57                                   Software Engineer            NICE Ltd
# 65                                   Software Engineer            NICE Ltd
# 91                    Principal Statistical Programmer                DOCS
# 120                                  Software Engineer            NICE Ltd
# 121                              Remote Perl Developer     Scopic Software
# 122                                  Software Engineer            NICE Ltd
# 123                   Principal Statistical Programmer                DOCS
# 11                               Sr. Platform Engineer                Aha!
# 30   Operations Intelligence Performance Optimizati...        SBM Offshore
# 65                               Sr. Platform Engineer                Aha!
# 77                              Ruby on Rails Engineer                Aha!
# 85   Software Development Specialist, Trilogy (Remo...  Crossover for Work
# 89                                       Data Engineer           Univision
# 120  Software Development Specialist, Trilogy (Remo...  Crossover for Work
# 121                              Sr. Platform Engineer                Aha!
# 122  Operations Intelligence Performance Optimizati...        SBM Offshore
# 123                              Sr. Platform Engineer                Aha!
# 124                             Ruby on Rails Engineer                Aha!
# 125                                      Data Engineer           Univision
#
#                                                    Url  \
# 67   https://cl.linkedin.com/jobs/view/data-scienti...
# 75   https://cl.linkedin.com/jobs/view/data-scienti...
# 7    https://co.linkedin.com/jobs/view/data-science...
# 36   https://co.linkedin.com/jobs/view/data-scienti...
# 72   https://co.linkedin.com/jobs/view/data-scienti...
# 73   https://co.linkedin.com/jobs/view/data-science...
# 41   https://ec.linkedin.com/jobs/view/devops-engin...
# 61   https://ec.linkedin.com/jobs/view/senior-pytho...
# 99   https://ec.linkedin.com/jobs/view/devops-engin...
# 100  https://ec.linkedin.com/jobs/view/senior-pytho...
# 36   https://br.linkedin.com/jobs/view/cientista-de...
# 44   https://br.linkedin.com/jobs/view/cientista-de...
# 100  https://br.linkedin.com/jobs/view/cientista-de...
# 101  https://br.linkedin.com/jobs/view/cientista-de...
# 33   https://ve.linkedin.com/jobs/view/software-eng...
# 66   https://ve.linkedin.com/jobs/view/software-eng...
# 95   https://ve.linkedin.com/jobs/view/software-eng...
# 96   https://ve.linkedin.com/jobs/view/software-eng...
# 2    https://uy.linkedin.com/jobs/view/desarrollado...
# 71   https://uy.linkedin.com/jobs/view/test-automat...
# 100  https://uy.linkedin.com/jobs/view/test-automat...
# 101  https://uy.linkedin.com/jobs/view/desarrollado...
# 42   https://py.linkedin.com/jobs/view/react-c%23-f...
# 58   https://py.linkedin.com/jobs/view/desarrollado...
# 94   https://py.linkedin.com/jobs/view/react-c%23-f...
# 95   https://py.linkedin.com/jobs/view/desarrollado...
# 12   https://bo.linkedin.com/jobs/view/remote-perl-...
# 57   https://bo.linkedin.com/jobs/view/software-eng...
# 65   https://bo.linkedin.com/jobs/view/software-eng...
# 91   https://bo.linkedin.com/jobs/view/principal-st...
# 120  https://bo.linkedin.com/jobs/view/software-eng...
# 121  https://bo.linkedin.com/jobs/view/remote-perl-...
# 122  https://bo.linkedin.com/jobs/view/software-eng...
# 123  https://bo.linkedin.com/jobs/view/principal-st...
# 11   https://gy.linkedin.com/jobs/view/sr-platform-...
# 30   https://gy.linkedin.com/jobs/view/operations-i...
# 65   https://gy.linkedin.com/jobs/view/sr-platform-...
# 77   https://gy.linkedin.com/jobs/view/ruby-on-rail...
# 85   https://gy.linkedin.com/jobs/view/software-dev...
# 89   https://gy.linkedin.com/jobs/view/data-enginee...
# 120  https://gy.linkedin.com/jobs/view/software-dev...
# 121  https://gy.linkedin.com/jobs/view/sr-platform-...
# 122  https://gy.linkedin.com/jobs/view/operations-i...
# 123  https://gy.linkedin.com/jobs/view/sr-platform-...
# 124  https://gy.linkedin.com/jobs/view/ruby-on-rail...
# 125  https://gy.linkedin.com/jobs/view/data-enginee...
#
#                             Postulaciones  \
# 67                                    NaN
# 75                                    NaN
# 7                                     NaN
# 36                                    NaN
# 72                                    NaN
# 73                                    NaN
# 41                                    NaN
# 61                                    NaN
# 99                                    NaN
# 100                                   NaN
# 36                                    NaN
# 44                                    NaN
# 100                                   NaN
# 101                                   NaN
# 33   \n          25 solicitudes\n
# 66                                    NaN
# 95                                    NaN
# 96   \n          25 solicitudes\n
# 2                                     NaN
# 71                                    NaN
# 100                                   NaN
# 101                                   NaN
# 42                                    NaN
# 58                                    NaN
# 94                                    NaN
# 95                                    NaN
# 12                                    NaN
# 57                                    NaN
# 65                                    NaN
# 91                                    NaN
# 120                                   NaN
# 121                                   NaN
# 122                                   NaN
# 123                                   NaN
# 11                                    NaN
# 30                                    NaN
# 65                                    NaN
# 77                                    NaN
# 85                                    NaN
# 89                                    NaN
# 120                                   NaN
# 121                                   NaN
# 122                                   NaN
# 123                                   NaN
# 124                                   NaN
# 125                                   NaN
#
#                                     Jornada  \
# 67                                      NaN
# 75                                      NaN
# 7    \n          Jornada completa\n
# 36                                      NaN
# 72                                      NaN
# 73   \n          Jornada completa\n
# 41                                      NaN
# 61   \n          Jornada completa\n
# 99                                      NaN
# 100  \n          Jornada completa\n
# 36     \n          Tempo integral\n
# 44     \n          Tempo integral\n
# 100    \n          Tempo integral\n
# 101    \n          Tempo integral\n
# 33   \n          Jornada completa\n
# 66   \n          Jornada completa\n
# 95   \n          Jornada completa\n
# 96   \n          Jornada completa\n
# 2                                       NaN
# 71                                      NaN
# 100                                     NaN
# 101                                     NaN
# 42                                      NaN
# 58                                      NaN
# 94                                      NaN
# 95                                      NaN
# 12   \n          Jornada completa\n
# 57                                      NaN
# 65   \n          Jornada completa\n
# 91                                      NaN
# 120                                     NaN
# 121  \n          Jornada completa\n
# 122  \n          Jornada completa\n
# 123                                     NaN
# 11                                      NaN
# 30          \n          Full-time\n
# 65          \n          Full-time\n
# 77          \n          Full-time\n
# 85                                      NaN
# 89          \n          Full-time\n
# 120                                     NaN
# 121                                     NaN
# 122         \n          Full-time\n
# 123         \n          Full-time\n
# 124         \n          Full-time\n
# 125         \n          Full-time\n
#
#                                      Antiguedad
# 67                                          NaN
# 75                                          NaN
# 7     \n            Sin experiencia\n
# 36                                          NaN
# 72                                          NaN
# 73    \n            Sin experiencia\n
# 41                                          NaN
# 61         \n            Intermedio\n
# 99                                          NaN
# 100        \n            Intermedio\n
# 36      \n            Não aplicável\n
# 44      \n            Não aplicável\n
# 100     \n            Não aplicável\n
# 101     \n            Não aplicável\n
# 33         \n            Intermedio\n
# 66         \n            Intermedio\n
# 95         \n            Intermedio\n
# 96         \n            Intermedio\n
# 2                                           NaN
# 71                                          NaN
# 100                                         NaN
# 101                                         NaN
# 42                                          NaN
# 58                                          NaN
# 94                                          NaN
# 95                                          NaN
# 12    \n            Sin experiencia\n
# 57                                          NaN
# 65    \n            Sin experiencia\n
# 91                                          NaN
# 120                                         NaN
# 121   \n            Sin experiencia\n
# 122   \n            Sin experiencia\n
# 123                                         NaN
# 11                                          NaN
# 30        \n            Entry level\n
# 65   \n            Mid-Senior level\n
# 77        \n            Entry level\n
# 85                                          NaN
# 89        \n            Entry level\n
# 120                                         NaN
# 121                                         NaN
# 122       \n            Entry level\n
# 123  \n            Mid-Senior level\n
# 124       \n            Entry level\n
# 125       \n            Entry level\n

# %%
alldf = alldf.drop_duplicates(subset=['Url'],keep='first')
alldf
# Out:
#     Country                                       Location  \
# 0     Chile  Santiago, Santiago Metropolitan Region, Chile
# 1     Chile  Santiago, Santiago Metropolitan Region, Chile
# 2     Chile  Santiago, Santiago Metropolitan Region, Chile
# 3     Chile              Rancagua, O'Higgins Region, Chile
# 4     Chile  Santiago, Santiago Metropolitan Region, Chile
# ..      ...                                            ...
# 115  Guyana              Mahaica, Demerara-Mahaica, Guyana
# 116  Guyana                                         Guyana
# 117  Guyana                                         Guyana
# 118  Guyana              Mahaica, Demerara-Mahaica, Guyana
# 119  Guyana              Mahaica, Demerara-Mahaica, Guyana
#
#                                                  Title         Company  \
# 0                                       Data Scientist       BICE VIDA
# 1                                       Data Scientist      BNamericas
# 2                                      Data Scientist.  Fuerza Laboral
# 3                                       Data Scientist       Agrosuper
# 4                                       Data Scientist   MAS Analytics
# ..                                                 ...             ...
# 115                        Lead Ruby on Rails Engineer            Aha!
# 116  Sr. Security Engineer (Ruby on Rails experienc...            Aha!
# 117                         Sr. Ruby on Rails Engineer            Aha!
# 118                         Sr. Ruby on Rails Engineer            Aha!
# 119  Sr. Security Engineer (Ruby on Rails experienc...            Aha!
#
#                                                    Url  \
# 0    https://cl.linkedin.com/jobs/view/data-scienti...
# 1    https://cl.linkedin.com/jobs/view/data-scienti...
# 2    https://cl.linkedin.com/jobs/view/data-scienti...
# 3    https://cl.linkedin.com/jobs/view/data-scienti...
# 4    https://cl.linkedin.com/jobs/view/data-scienti...
# ..                                                 ...
# 115  https://gy.linkedin.com/jobs/view/lead-ruby-on...
# 116  https://gy.linkedin.com/jobs/view/sr-security-...
# 117  https://gy.linkedin.com/jobs/view/sr-ruby-on-r...
# 118  https://gy.linkedin.com/jobs/view/sr-ruby-on-r...
# 119  https://gy.linkedin.com/jobs/view/sr-security-...
#
#                             Postulaciones  \
# 0                                     NaN
# 1    \n          42 solicitudes\n
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 115                                   NaN
# 116                                   NaN
# 117                                   NaN
# 118                                   NaN
# 119                                   NaN
#
#                                     Jornada  \
# 0    \n          Jornada completa\n
# 1    \n          Jornada completa\n
# 2    \n          Jornada completa\n
# 3    \n          Jornada completa\n
# 4    \n          Jornada completa\n
# ..                                      ...
# 115                                     NaN
# 116                                     NaN
# 117         \n          Full-time\n
# 118                                     NaN
# 119         \n          Full-time\n
#
#                                      Antiguedad
# 0      \n            No corresponde\n
# 1     \n            Sin experiencia\n
# 2     \n            Sin experiencia\n
# 3          \n            Intermedio\n
# 4      \n            No corresponde\n
# ..                                          ...
# 115                                         NaN
# 116                                         NaN
# 117  \n            Mid-Senior level\n
# 118                                         NaN
# 119  \n            Mid-Senior level\n
#
# [1000 rows x 8 columns]

# %% [markdown]
# ### 4. Convierta la columna *Postulaciones* a un dato de tipo numérico.
#
# **a)** Chequee los valores únicos de la columna *Postulaciones*.<br>
# **b)** Realice las correcciones y operaciones de limpieza necesarias para convertir a tipo de dato numérico.<br>
# **c)** Convierta la columna a datos de tipo `float`.<br>
#
#
# *Funciones útiles*: `pandas.unique()`,`pandas.str.replace()`,`pandas.str.strip()`,`pandas.astype()`

# %%
#completar código
alldf['Postulaciones'].unique()
# Out:
# array([nan, '\n          42 solicitudes\n        ',
#        '\n          38 solicitudes\n        ',
#        '\n          135 solicitudes\n        ',
#        '\n          40 solicitudes\n        ',
#        '\n          104 solicitudes\n        ',
#        '\n          91 solicitudes\n        ',
#        '\n          80 solicitudes\n        ',
#        '\n          106 solicitudes\n        ',
#        '\n          174 solicitudes\n        ',
#        '\n          53 solicitudes\n        ',
#        '\n          32 solicitudes\n        ',
#        '\n          85 solicitudes\n        ',
#        '\n          43 solicitudes\n        ',
#        '\n          44 solicitudes\n        ',
#        '\n          47 solicitudes\n        ',
#        '\n          33 solicitudes\n        ',
#        '\n          55 solicitudes\n        ',
#        '\n          58 solicitudes\n        ',
#        '\n          29 solicitudes\n        ',
#        '\n          153 solicitudes\n        ',
#        '\n          95 solicitudes\n        ',
#        '\n          54 applicants\n        ',
#        '\n          41 solicitudes\n        ',
#        '\n          83 solicitudes\n        ',
#        '\n          111 applicants\n        ',
#        '\n          150 solicitudes\n        ',
#        '\n          30 solicitudes\n        ',
#        '\n          124 solicitudes\n        ',
#        '\n          72 solicitudes\n        ',
#        '\n          92 solicitudes\n        ',
#        '\n          35 solicitudes\n        ',
#        '\n          36 solicitudes\n        ',
#        '\n          27 solicitudes\n        ',
#        '\n          81 solicitudes\n        ',
#        '\n          76 solicitudes\n        ',
#        '\n          112 solicitudes\n        ',
#        '\n          57 solicitudes\n        ',
#        '\n          39 solicitudes\n        ',
#        '\n          60 solicitudes\n        ',
#        '\n          59 applicants\n        ',
#        '\n          94 applicants\n        ',
#        '\n          60 applicants\n        ',
#        '\n          191 applicants\n        ',
#        '\n          129 applicants\n        ',
#        '\n          151 applicants\n        ',
#        '\n          178 applicants\n        ',
#        '\n          180 applicants\n        ',
#        '\n          77 applicants\n        ',
#        '\n          194 applicants\n        ',
#        '\n          187 applicants\n        ',
#        '\n          53 applicants\n        ',
#        '\n          35 candidaturas\n        ',
#        '\n          151 candidaturas\n        ',
#        '\n          165 candidaturas\n        ',
#        '\n          116 candidaturas\n        ',
#        '\n          41 applicants\n        ',
#        '\n          43 applicants\n        ',
#        '\n          119 applicants\n        ',
#        '\n          62 applicants\n        ',
#        '\n          115 candidaturas\n        ',
#        '\n          106 candidaturas\n        ',
#        '\n          110 candidaturas\n        ',
#        '\n          185 candidaturas\n        ',
#        '\n          64 candidaturas\n        ',
#        '\n          29 candidaturas\n        ',
#        '\n          25 solicitudes\n        ',
#        '\n          65 solicitudes\n        ',
#        '\n          49 solicitudes\n        ',
#        '\n          51 solicitudes\n        ',
#        '\n          28 solicitudes\n        ',
#        '\n          26 solicitudes\n        ',
#        '\n          156 solicitudes\n        ',
#        '\n          52 solicitudes\n        ',
#        '\n          67 solicitudes\n        ',
#        '\n          56 solicitudes\n        ',
#        '\n          152 solicitudes\n        ',
#        '\n          82 solicitudes\n        ',
#        '\n          155 solicitudes\n        ',
#        '\n          37 solicitudes\n        ',
#        '\n          71 solicitudes\n        ',
#        '\n          79 solicitudes\n        ',
#        '\n          34 solicitudes\n        '], dtype=object)

# %%
alldf
# Out:
#     Country                                       Location  \
# 0     Chile  Santiago, Santiago Metropolitan Region, Chile
# 1     Chile  Santiago, Santiago Metropolitan Region, Chile
# 2     Chile  Santiago, Santiago Metropolitan Region, Chile
# 3     Chile              Rancagua, O'Higgins Region, Chile
# 4     Chile  Santiago, Santiago Metropolitan Region, Chile
# ..      ...                                            ...
# 115  Guyana              Mahaica, Demerara-Mahaica, Guyana
# 116  Guyana                                         Guyana
# 117  Guyana                                         Guyana
# 118  Guyana              Mahaica, Demerara-Mahaica, Guyana
# 119  Guyana              Mahaica, Demerara-Mahaica, Guyana
#
#                                                  Title         Company  \
# 0                                       Data Scientist       BICE VIDA
# 1                                       Data Scientist      BNamericas
# 2                                      Data Scientist.  Fuerza Laboral
# 3                                       Data Scientist       Agrosuper
# 4                                       Data Scientist   MAS Analytics
# ..                                                 ...             ...
# 115                        Lead Ruby on Rails Engineer            Aha!
# 116  Sr. Security Engineer (Ruby on Rails experienc...            Aha!
# 117                         Sr. Ruby on Rails Engineer            Aha!
# 118                         Sr. Ruby on Rails Engineer            Aha!
# 119  Sr. Security Engineer (Ruby on Rails experienc...            Aha!
#
#                                                    Url  \
# 0    https://cl.linkedin.com/jobs/view/data-scienti...
# 1    https://cl.linkedin.com/jobs/view/data-scienti...
# 2    https://cl.linkedin.com/jobs/view/data-scienti...
# 3    https://cl.linkedin.com/jobs/view/data-scienti...
# 4    https://cl.linkedin.com/jobs/view/data-scienti...
# ..                                                 ...
# 115  https://gy.linkedin.com/jobs/view/lead-ruby-on...
# 116  https://gy.linkedin.com/jobs/view/sr-security-...
# 117  https://gy.linkedin.com/jobs/view/sr-ruby-on-r...
# 118  https://gy.linkedin.com/jobs/view/sr-ruby-on-r...
# 119  https://gy.linkedin.com/jobs/view/sr-security-...
#
#                             Postulaciones  \
# 0                                     NaN
# 1    \n          42 solicitudes\n
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 115                                   NaN
# 116                                   NaN
# 117                                   NaN
# 118                                   NaN
# 119                                   NaN
#
#                                     Jornada  \
# 0    \n          Jornada completa\n
# 1    \n          Jornada completa\n
# 2    \n          Jornada completa\n
# 3    \n          Jornada completa\n
# 4    \n          Jornada completa\n
# ..                                      ...
# 115                                     NaN
# 116                                     NaN
# 117         \n          Full-time\n
# 118                                     NaN
# 119         \n          Full-time\n
#
#                                      Antiguedad
# 0      \n            No corresponde\n
# 1     \n            Sin experiencia\n
# 2     \n            Sin experiencia\n
# 3          \n            Intermedio\n
# 4      \n            No corresponde\n
# ..                                          ...
# 115                                         NaN
# 116                                         NaN
# 117  \n            Mid-Senior level\n
# 118                                         NaN
# 119  \n            Mid-Senior level\n
#
# [1000 rows x 8 columns]

# %%
alldf['Postulaciones'] = alldf['Postulaciones'].apply(lambda x: str(x).replace('\n', '').replace('solicitudes', '').replace('candidaturas', '').replace('applicants', '').strip()).astype(np.float64)
# Out:
# C:\Users\Erick\AppData\Local\Temp\ipykernel_12720\858967996.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alldf['Postulaciones'] = alldf['Postulaciones'].apply(lambda x: str(x).replace('\n', '').replace('solicitudes', '').replace('candidaturas', '').replace('applicants', '').strip()).astype(np.float64)

# %%
alldf
# Out:
#     Country                                       Location  \
# 0     Chile  Santiago, Santiago Metropolitan Region, Chile
# 1     Chile  Santiago, Santiago Metropolitan Region, Chile
# 2     Chile  Santiago, Santiago Metropolitan Region, Chile
# 3     Chile              Rancagua, O'Higgins Region, Chile
# 4     Chile  Santiago, Santiago Metropolitan Region, Chile
# ..      ...                                            ...
# 115  Guyana              Mahaica, Demerara-Mahaica, Guyana
# 116  Guyana                                         Guyana
# 117  Guyana                                         Guyana
# 118  Guyana              Mahaica, Demerara-Mahaica, Guyana
# 119  Guyana              Mahaica, Demerara-Mahaica, Guyana
#
#                                                  Title         Company  \
# 0                                       Data Scientist       BICE VIDA
# 1                                       Data Scientist      BNamericas
# 2                                      Data Scientist.  Fuerza Laboral
# 3                                       Data Scientist       Agrosuper
# 4                                       Data Scientist   MAS Analytics
# ..                                                 ...             ...
# 115                        Lead Ruby on Rails Engineer            Aha!
# 116  Sr. Security Engineer (Ruby on Rails experienc...            Aha!
# 117                         Sr. Ruby on Rails Engineer            Aha!
# 118                         Sr. Ruby on Rails Engineer            Aha!
# 119  Sr. Security Engineer (Ruby on Rails experienc...            Aha!
#
#                                                    Url  Postulaciones  \
# 0    https://cl.linkedin.com/jobs/view/data-scienti...            NaN
# 1    https://cl.linkedin.com/jobs/view/data-scienti...           42.0
# 2    https://cl.linkedin.com/jobs/view/data-scienti...            NaN
# 3    https://cl.linkedin.com/jobs/view/data-scienti...            NaN
# 4    https://cl.linkedin.com/jobs/view/data-scienti...            NaN
# ..                                                 ...            ...
# 115  https://gy.linkedin.com/jobs/view/lead-ruby-on...            NaN
# 116  https://gy.linkedin.com/jobs/view/sr-security-...            NaN
# 117  https://gy.linkedin.com/jobs/view/sr-ruby-on-r...            NaN
# 118  https://gy.linkedin.com/jobs/view/sr-ruby-on-r...            NaN
# 119  https://gy.linkedin.com/jobs/view/sr-security-...            NaN
#
#                                     Jornada  \
# 0    \n          Jornada completa\n
# 1    \n          Jornada completa\n
# 2    \n          Jornada completa\n
# 3    \n          Jornada completa\n
# 4    \n          Jornada completa\n
# ..                                      ...
# 115                                     NaN
# 116                                     NaN
# 117         \n          Full-time\n
# 118                                     NaN
# 119         \n          Full-time\n
#
#                                      Antiguedad
# 0      \n            No corresponde\n
# 1     \n            Sin experiencia\n
# 2     \n            Sin experiencia\n
# 3          \n            Intermedio\n
# 4      \n            No corresponde\n
# ..                                          ...
# 115                                         NaN
# 116                                         NaN
# 117  \n            Mid-Senior level\n
# 118                                         NaN
# 119  \n            Mid-Senior level\n
#
# [1000 rows x 8 columns]

# %% [markdown]
# ### 5. Convierta las columnas *Jornada* y *Antiguedad* a datos de tipo categórico.
#
# **a)** Elimine los espacios en blanco sobrantes y caracteres de salto de línea ('\n') en ambas columnas.<br>
# **b)** Chequee las categorías únicas de la columna *Jornada*. ¿Cuántas son? <br>
# **c)** Para la columna *Antiguedad*, reduzca el número de categorías a sólo cuatro:`['N/A','Poca/ninguna','Intermedia','Senior/ejecutivo','Director']` (`N/A: no aplica`). <br>Para ello, defina un diccionario de equivalencias que le parezca adecuado.
#
# **d)** Convierta ambas columnas a datos de tipo `category`.<br>
#
# *Funciones útiles*: `pandas.unique()`,`pandas.str.strip()`,`pandas.map()`,`pandas.astype()`

# %% [markdown]
# **Respuesta**
# b) son hay 5 jornadas. Hay 6 si contamos los registros con nulos.

# %%
alldf['Jornada'] = alldf['Jornada'].apply(lambda x: str(x).replace('\n', '').strip())
alldf['Antiguedad'] = alldf['Antiguedad'].apply(lambda x: str(x).replace('\n', '').strip())
# Out:
# C:\Users\Erick\AppData\Local\Temp\ipykernel_12720\2165973118.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alldf['Jornada'] = alldf['Jornada'].apply(lambda x: str(x).replace('\n', '').strip())
# C:\Users\Erick\AppData\Local\Temp\ipykernel_12720\2165973118.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alldf['Antiguedad'] = alldf['Antiguedad'].apply(lambda x: str(x).replace('\n', '').strip())

# %%
alldf['Jornada'].unique()
# Out:
# array(['Jornada completa', 'nan', 'Full-time', 'Tempo integral',
#        'Contract', 'Contrato por obra'], dtype=object)

# %%
alldf['Antiguedad'].unique()
# Out:
# array(['No corresponde', 'Sin experiencia', 'Intermedio', 'nan',
#        'Algo de responsabilidad', 'Ejecutivo', 'Entry level',
#        'Jornada completa', 'Director', 'Associate', 'Not Applicable',
#        'Mid-Senior level', 'Assistente', 'Não aplicável', 'Pleno-sênior',
#        'Júnior', 'Media jornada', 'Full-time'], dtype=object)

# %%
sustituciones = {
    'No corresponde': 'N/A',
    'Sin experiencia': 'Poca/ninguna',
    'nan': 'N/A',
    'Algo de responsabilidad': 'Poca/ninguna',
    'Ejecutivo': 'Senior/ejecutivo',
    'Entry level': 'Poca/ninguna',
    'Jornada completa': 'Poca/ninguna', 
    'Director': 'Director',
    'Associate': 'Intermedia',
    'Not Applicable': 'N/A',
    'Mid-Senior level': 'Intermedia',
    'Assistente': 'Poca/ninguna',
    'Não aplicável': 'N/A',
    'Pleno-sênior': 'Senior/ejecutivo',
    'Júnior': 'Poca/ninguna',
    'Media jornada': 'Poca/ninguna',
    'Full-time': 'Poca/ninguna'
}

alldf['Antiguedad'] = alldf['Antiguedad'].replace(sustituciones)
alldf['Antiguedad'].unique()
# Out:
# C:\Users\Erick\AppData\Local\Temp\ipykernel_12720\1531706022.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alldf['Antiguedad'] = alldf['Antiguedad'].replace(sustituciones)
# array(['N/A', 'Poca/ninguna', 'Intermedio', 'Senior/ejecutivo',
#        'Director', 'Intermedia'], dtype=object)

# %%
alldf['Jornada'] = alldf['Jornada'].astype('category')
alldf['Antiguedad'] = alldf['Antiguedad'].astype('category')
# Out:
# C:\Users\Erick\AppData\Local\Temp\ipykernel_12720\3553063426.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alldf['Jornada'] = alldf['Jornada'].astype('category')
# C:\Users\Erick\AppData\Local\Temp\ipykernel_12720\3553063426.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alldf['Antiguedad'] = alldf['Antiguedad'].astype('category')

# %%
alldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 119
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country        1000 non-null   object
#  1   Location       1000 non-null   object
#  2   Title          1000 non-null   object
#  3   Company        1000 non-null   object
#  4   Url            1000 non-null   object
#  5   Postulaciones  182 non-null    float64
#  6   Jornada        1000 non-null   category
#  7   Antiguedad     1000 non-null   category
# dtypes: category(2), float64(1), object(5)
# memory usage: 57.1+ KB

# %%
alldf.head()
# Out:
#   Country                                       Location            Title  \
# 0   Chile  Santiago, Santiago Metropolitan Region, Chile   Data Scientist
# 1   Chile  Santiago, Santiago Metropolitan Region, Chile   Data Scientist
# 2   Chile  Santiago, Santiago Metropolitan Region, Chile  Data Scientist.
# 3   Chile              Rancagua, O'Higgins Region, Chile   Data Scientist
# 4   Chile  Santiago, Santiago Metropolitan Region, Chile   Data Scientist
#
#           Company                                                Url  \
# 0       BICE VIDA  https://cl.linkedin.com/jobs/view/data-scienti...
# 1      BNamericas  https://cl.linkedin.com/jobs/view/data-scienti...
# 2  Fuerza Laboral  https://cl.linkedin.com/jobs/view/data-scienti...
# 3       Agrosuper  https://cl.linkedin.com/jobs/view/data-scienti...
# 4   MAS Analytics  https://cl.linkedin.com/jobs/view/data-scienti...
#
#    Postulaciones           Jornada    Antiguedad
# 0            NaN  Jornada completa           N/A
# 1           42.0  Jornada completa  Poca/ninguna
# 2            NaN  Jornada completa  Poca/ninguna
# 3            NaN  Jornada completa    Intermedio
# 4            NaN  Jornada completa           N/A

# %% [markdown]
# ### 6. Lea el conjunto de datos de Índice de Innovación por país y renombre la columna *Economy* a *Country*.

# %%
indice_innovacion = pd.read_csv('https://raw.githubusercontent.com/paguirre-uc/mds3020_2022/main/tarea2/indiceInnovacionPaises.csv')
indice_innovacion = indice_innovacion.rename(columns={'Economy': 'Country'})

# %%
indice_innovacion.head()
# Out:
#                     Country  Score
# 0               Switzerland   64.6
# 1  United States of America   61.8
# 2                    Sweden   61.6
# 3            United Kingdom   59.7
# 4               Netherlands   58.0

# %% [markdown]
# ### 7. Combinación de conjuntos de datos.
# **a)** Del dataframe de Índice de Innovación por País, seleccione sólo las columnas *Country* y *Score*. <br>
# **b)** Combine estos datos con el dataframe de ofertas laborales, de manera de agregarle a éste una columna *Score* con el índice de innovación del país dónde se publicó el anuncio: <br>
#
# |Country | Location|Title | Company | Url | Postulaciones | Jornada |Antiguedad |Score |
# |---|---|---|---|---|---|---|---|---|
#
# Este dataframe debe tener el mismo número de registros que el dataframe de ofertas laborales.
#
# **b)** Determine si en este dataframe final, existen registros para los cuales la columna *Score* es un dato faltante o nulo. ¿A qué se deben estos datos nulos, si es que existen?
#
# *Funciones útiles*: `pandas.merge()`

# %% [markdown]
# **Respuesta**: Si, hay 485 registros nulos. Existen registros nulos en los casos en los que los países están escritos de manera diferente en las bases. También pueden existir nulos porque algunos países de la base de datos de ofertas laborales no se encuentran en la base de datos de innovación.
#
# En este caso, Score presenta nulos porque lgunos países de la base de datos de ofertas laborales no se encuentran en la base de datos de innovación, específicamente Brasil, Venezuela, Bolivia, Suriname, Guyana

# %%
indice_innovacion = indice_innovacion[['Country', 'Score']]
indice_innovacion_aux = indice_innovacion[['Country', 'Score']].copy() # lo hago para identificar los paises escritos diferente
indice_innovacion_aux['Country_auxs'] = indice_innovacion_aux['Country']
indice_innovacion.duplicated().sum()
# Out:
# np.int64(0)

# %%
ofertas_laborales_completo = pd.merge(
    left=alldf,
    right=indice_innovacion,
    left_on = 'Country',
    right_on = 'Country',
    how='left'
)


ofertas_laborales_completo_aux = pd.merge(
    left=alldf,
    right=indice_innovacion_aux,
    left_on = 'Country',
    right_on = 'Country',
    how='left'
)
assert len(ofertas_laborales_completo==len(alldf))

# %%
ofertas_laborales_completo['Score'].isna().sum()
# Out:
# np.int64(485)

# %%
ofertas_laborales_completo_aux.loc[ofertas_laborales_completo_aux['Score'].isna()]['Country'].unique()
# Out:
# array(['Brasil', 'Venezuela', 'Bolivia', 'Suriname', 'Guyana'],
#       dtype=object)

# %%
ofertas_laborales_completo
# Out:
#     Country                                       Location  \
# 0     Chile  Santiago, Santiago Metropolitan Region, Chile
# 1     Chile  Santiago, Santiago Metropolitan Region, Chile
# 2     Chile  Santiago, Santiago Metropolitan Region, Chile
# 3     Chile              Rancagua, O'Higgins Region, Chile
# 4     Chile  Santiago, Santiago Metropolitan Region, Chile
# ..      ...                                            ...
# 995  Guyana              Mahaica, Demerara-Mahaica, Guyana
# 996  Guyana                                         Guyana
# 997  Guyana                                         Guyana
# 998  Guyana              Mahaica, Demerara-Mahaica, Guyana
# 999  Guyana              Mahaica, Demerara-Mahaica, Guyana
#
#                                                  Title         Company  \
# 0                                       Data Scientist       BICE VIDA
# 1                                       Data Scientist      BNamericas
# 2                                      Data Scientist.  Fuerza Laboral
# 3                                       Data Scientist       Agrosuper
# 4                                       Data Scientist   MAS Analytics
# ..                                                 ...             ...
# 995                        Lead Ruby on Rails Engineer            Aha!
# 996  Sr. Security Engineer (Ruby on Rails experienc...            Aha!
# 997                         Sr. Ruby on Rails Engineer            Aha!
# 998                         Sr. Ruby on Rails Engineer            Aha!
# 999  Sr. Security Engineer (Ruby on Rails experienc...            Aha!
#
#                                                    Url  Postulaciones  \
# 0    https://cl.linkedin.com/jobs/view/data-scienti...            NaN
# 1    https://cl.linkedin.com/jobs/view/data-scienti...           42.0
# 2    https://cl.linkedin.com/jobs/view/data-scienti...            NaN
# 3    https://cl.linkedin.com/jobs/view/data-scienti...            NaN
# 4    https://cl.linkedin.com/jobs/view/data-scienti...            NaN
# ..                                                 ...            ...
# 995  https://gy.linkedin.com/jobs/view/lead-ruby-on...            NaN
# 996  https://gy.linkedin.com/jobs/view/sr-security-...            NaN
# 997  https://gy.linkedin.com/jobs/view/sr-ruby-on-r...            NaN
# 998  https://gy.linkedin.com/jobs/view/sr-ruby-on-r...            NaN
# 999  https://gy.linkedin.com/jobs/view/sr-security-...            NaN
#
#               Jornada    Antiguedad  Score
# 0    Jornada completa           N/A   34.0
# 1    Jornada completa  Poca/ninguna   34.0
# 2    Jornada completa  Poca/ninguna   34.0
# 3    Jornada completa    Intermedio   34.0
# 4    Jornada completa           N/A   34.0
# ..                ...           ...    ...
# 995               nan           N/A    NaN
# 996               nan           N/A    NaN
# 997         Full-time    Intermedia    NaN
# 998               nan           N/A    NaN
# 999         Full-time    Intermedia    NaN
#
# [1000 rows x 9 columns]
